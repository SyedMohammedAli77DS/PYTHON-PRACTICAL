# %%
type(product_det)
# Out:
# str

# %%
product_det ='{"itemid":1001,"Description":"GPU-LX001","Qty":1000,"Price":5000.00,"Taxable":"True"}'

# %%
product_det
# Out:
# '{"itemid":1001,"Description":"GPU-LX001","Qty":1000,"Price":5000.00,"Taxable":"True"}'

# %%
product_obj = (product_det)

# %%
product_obj
# Out:
# '{"itemid":1001,"Description":"GPU-LX001","Qty":1000,"Price":5000.00,"Taxable":"True"}'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
emp = pd.read_csv('employee.csv')
dept = pd.read_csv('department.csv')

# %%
emp
# Out:
# {'empid': 1001,
#  'fullname': 'Abc xyz',
#  'salary': 50000.0,
#  'skill': 'Data Analytics'}

# %%
emp = pd.read_csv("employee.csv",encoding='utf-8')

# %%
emp
# Out:
# {'empid': 1001,
#  'fullname': 'Abc xyz',
#  'salary': 50000.0,
#  'skill': 'Data Analytics'}

# %%
dept
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-2d8d357adc72> in <module>()
# ----> 1 dept
#
# NameError: name 'dept' is not defined

# %%
emp
# Out:
# {'empid': 1001,
#  'fullname': 'Abc xyz',
#  'salary': 50000.0,
#  'skill': 'Data Analytics'}

# %%
import csv

# %%
import numpy as np
import pandas as pd
employee = pd.read_xlxs('c:/Users/admin/Downloads/Data Science Practical/Data Set/employee.xlxs')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-f9100ce9b12c> in <module>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 employee = pd.read_xlxs('c:/Users/admin/Downloads/Data Science Practical/Data Set/employee.xlxs')
#
# AttributeError: module 'pandas' has no attribute 'read_xlxs'

# %%
cust = {"name":["A","B","C"], "city":["Hyd","Pune","Mum"],"gen_age":["M30","M25","F25"]}

# %%
cust
# Out:
# {'name': ['A', 'B', 'C'],
#  'city': ['Hyd', 'Pune', 'Mum'],
#  'gen_age': ['M30', 'M25', 'F25']}

# %%
custdf = pd.DataFrame(cust)

# %%
custdf
# Out:
#   name  city gen_age
# 0    A   Hyd     M30
# 1    B  Pune     M25
# 2    C   Mum     F25

# %%
custdf["Gender"]=custdf.gen_age.str[0]

# %%
custdf
# Out:
#   name  city gen_age Gender  age
# 0    A   Hyd     M30      M  M30
# 1    B  Pune     M25      M  M25
# 2    C   Mum     F25      F  F25

# %%
custdf["age"]=custdf.gen_age

# %%
custdf
# Out:
#   name  city gen_age Gender  age
# 0    A   Hyd     M30      M  M30
# 1    B  Pune     M25      M  M25
# 2    C   Mum     F25      F  F25

# %%
custdf["Gender"]=custdf.gen_age.str[0]

# %%
custdf
# Out:
#   name  city gen_age Gender  age
# 0    A   Hyd     M30      M  M30
# 1    B  Pune     M25      M  M25
# 2    C   Mum     F25      F  F25

# %%
custdf["age"]=custdf.gen_age.Str[0]

# %%
custdf
# Out:
#   name  city gen_age Gender  age
# 0    A   Hyd     M30      M  M30
# 1    B  Pune     M25      M  M25
# 2    C   Mum     F25      F  F25

# %%
Book = pd.read_csv 'Users\admin\Downloads\Data Set\Book.csv'
# Out:
#   File "<ipython-input-104-1fb0b61296eb>", line 1
#     Book = pd.read_csv 'Users\admin\Downloads\Data Set\Book.csv'
#                                                                ^
# SyntaxError: invalid syntax

# %%
custdf["age"]=custdf.gen_age.str[1:3]

# %%
custdf
# Out:
#   name  city gen_age Gender age
# 0    A   Hyd     M30      M  30
# 1    B  Pune     M25      M  25
# 2    C   Mum     F25      F  25

# %%
rating = [1,2,3]

# %%
ratingdf = pd.DataFrame(rating)

# %%
ratingdf
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
import csv     # csv

# %%
# !ls *csv
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
lines = [line for line in open('d:/datasets/employee.csv')]

# %%
lines[1]
# Out:
# '0,10,ind-001,Abdul Rehman,CSO,100000,,1\n'

# %%
lines[2]
# Out:
# '1,20,ind-002,M. Yousuf,CTO,90000,ind-001,1\n'

# %%
lines[3]
# Out:
# "2,30,ind-003,Joseph D'Souza,CVO,84000,ind-001,1\n"

# %%
lines[1].strip().split(',')
# Out:
# ['0', '10', 'ind-001', 'Abdul Rehman', 'CSO', '100000', '', '1']

# %%
lines[5].strip().split(',')
# Out:
# ['4', '50', 'us-001', 'Jogender Singh', 'STO', '56000', 'ind-002', '2']

# %%
lines[3].strip().split(',')
# Out:
# ['2', '30', 'ind-003', "Joseph D'Souza", 'CVO', '84000', 'ind-001', '1']

# %%
lines
# Out:
# [',dno,employee id,fullname,position,salary,manager id,department id\n',
#  '0,10,ind-001,Abdul Rehman,CSO,100000,,1\n',
#  '1,20,ind-002,M. Yousuf,CTO,90000,ind-001,1\n',
#  "2,30,ind-003,Joseph D'Souza,CVO,84000,ind-001,1\n",
#  '3,40,ind-004,Mahesh Kalmadi,CWO,70000,ind-002,2\n',
#  '4,50,us-001,Jogender Singh,STO,56000,ind-002,2\n',
#  '5,60,us-002,Syed Mannan,SPO,56000,ind-003,3\n',
#  '6,70,dub-001,John,CTO,50000,ind-002,0\n']

# %%
for l in open('d:/datasets/employee.csv'):
    print (type(l))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
l
# Out:
# '6,70,dub-001,John,CTO,50000,ind-002,0\n'

# %%
l
# Out:
# '6,70,dub-001,John,CTO,50000,ind-002,0\n'

# %%
import csv
path = 'd:/datasets/employee.csv'
file = open(path)
reader = csv.reader(file)
header = next(reader)
for row in reader:
    print (row)
# Out:
# ['0', '10', 'ind-001', 'Abdul Rehman', 'CSO', '100000', '', '1']
# ['1', '20', 'ind-002', 'M. Yousuf', 'CTO', '90000', 'ind-001', '1']
# ['2', '30', 'ind-003', "Joseph D'Souza", 'CVO', '84000', 'ind-001', '1']
# ['3', '40', 'ind-004', 'Mahesh Kalmadi', 'CWO', '70000', 'ind-002', '2']
# ['4', '50', 'us-001', 'Jogender Singh', 'STO', '56000', 'ind-002', '2']
# ['5', '60', 'us-002', 'Syed Mannan', 'SPO', '56000', 'ind-003', '3']
# ['6', '70', 'dub-001', 'John', 'CTO', '50000', 'ind-002', '0']

# %%
[line for line in open('d:/datasets/employee.csv') ]
# Out:
# [',dno,employee id,fullname,position,salary,manager id,department id\n',
#  '0,10,ind-001,Abdul Rehman,CSO,100000,,1\n',
#  '1,20,ind-002,M. Yousuf,CTO,90000,ind-001,1\n',
#  "2,30,ind-003,Joseph D'Souza,CVO,84000,ind-001,1\n",
#  '3,40,ind-004,Mahesh Kalmadi,CWO,70000,ind-002,2\n',
#  '4,50,us-001,Jogender Singh,STO,56000,ind-002,2\n',
#  '5,60,us-002,Syed Mannan,SPO,56000,ind-003,3\n',
#  '6,70,dub-001,John,CTO,50000,ind-002,0\n']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
emp = pd.read_csv('d:/datasets/employee.csv')
dept = pd.read_csv('d:/datasets/department.csv')

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
dept
# Out:
#    Unnamed: 0  dno    dname       loc
# 0           0   10  finance       hyd
# 1           1   20       hr    mumbai
# 2           2   30       IT     delhi
# 3           3   40      Rnd  calcutta
# 4           4   50  testing    madras
# 5           5   60   coding  banglore

# %%
emp.columns
# Out:
# Index(['Unnamed: 0', 'dno', 'employee id', 'fullname', 'position', 'salary',
#        'manager id', 'department id'],
#       dtype='object')

# %%
dept.columns
# Out:
# Index(['Unnamed: 0', 'dno', 'dname', 'loc'], dtype='object')

# %%
emp.columns = emp.columns.str.replace(" ","_")

# %%
emp.columns
# Out:
# Index(['Unnamed:_0', 'dno', 'employee_id', 'fullname', 'position', 'salary',
#        'manager_id', 'department_id'],
#       dtype='object')

# %%
emp.columns = emp.columns.str.lower()

# %%
emp.columns
# Out:
# Index(['unnamed:_0', 'dno', 'employee_id', 'fullname', 'position', 'salary',
#        'manager_id', 'department_id'],
#       dtype='object')

# %%
emp.columns=[c.replace(" ","_").upper() for c in emp.columns]

# %%
emp.columns
# Out:
# Index(['UNNAMED:_0', 'DNO', 'EMPLOYEE_ID', 'FULLNAME', 'POSITION', 'SALARY',
#        'MANAGER_ID', 'DEPARTMENT_ID'],
#       dtype='object')

# %%
emp.rename(columns={'employee_id':'empid','department_id':'deptid'})
# Out:
#    UNNAMED:_0  DNO EMPLOYEE_ID        FULLNAME POSITION  SALARY MANAGER_ID  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    DEPARTMENT_ID
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp
# Out:
#    UNNAMED:_0  DNO EMPLOYEE_ID        FULLNAME POSITION  SALARY MANAGER_ID  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    DEPARTMENT_ID
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp.head()
# Out:
#    UNNAMED:_0  DNO EMPLOYEE_ID        FULLNAME POSITION  SALARY MANAGER_ID  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
#
#    DEPARTMENT_ID
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2

# %% [markdown]
# Missing data

# %%
emp.iloc[2,2] = np.NaN

# %%
emp.isnull()
# Out:
#    UNNAMED:_0    DNO  EMPLOYEE_ID  FULLNAME  POSITION  SALARY  MANAGER_ID  \
# 0       False  False        False     False     False   False        True
# 1       False  False        False     False     False   False       False
# 2       False  False         True     False     False   False       False
# 3       False  False        False     False     False   False       False
# 4       False  False        False     False     False   False       False
# 5       False  False        False     False     False   False       False
# 6       False  False        False     False     False   False       False
#
#    DEPARTMENT_ID
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False

# %%
emp
# Out:
#    UNNAMED:_0  DNO EMPLOYEE_ID        FULLNAME POSITION  SALARY MANAGER_ID  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30         NaN  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    DEPARTMENT_ID
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp.iloc[2,2]
# Out:
# nan

# %%
emp.iloc[1,1]
# Out:
# 20

# %%
emp.iloc[2,3]
# Out:
# "Joseph D'Souza"

# %%
emp.isnull().any().any()     #  any null throughout dataframe
# Out:
# True

# %%
emp.isnull().sum()    # tot no. of null values in each column
# Out:
# UNNAMED:_0       0
# DNO              0
# EMPLOYEE_ID      1
# FULLNAME         0
# POSITION         0
# SALARY           0
# MANAGER_ID       1
# DEPARTMENT_ID    0
# dtype: int64

# %%
emp.isnull().sum().sum()   # Total no. of nulls throughout dataframe
# Out:
# 2

# %%
import pandas as pd
emp=pd.read_csv("d:/datasets/employee.csv")

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp.fillna(0)
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000          0
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
import numpy as np
emp.iloc[3,3] = np.NaN

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004             NaN      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-94640616605f> in <module>()
# ----> 1 emp
#
# NameError: name 'emp' is not defined

# %%
import pandas as pd
emp=pd.read_csv("d:/datasets/employee.csv")

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
avgsal= emp['salary'].mean()

# %%
avgsal
# Out:
# 72285.71428571429

# %%
emp.salary.fillna(avgsal)
#print(avgsal)
# Out:
# 0    100000
# 1     90000
# 2     84000
# 3     70000
# 4     56000
# 5     56000
# 6     50000
# Name: salary, dtype: int64

# %%
emp_nonull = emp.dropna()   #Threshold (upper limit)

# %%
emp_nonull
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp_nonull.dropna(axis=1,inplace=True)    # drop entire column/s with null/s
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
emp_nonull
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
import numpy as np
emp.iloc[1,4] = np.NaN

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      NaN   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      NaN   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp.dropna(axis=0)   # drop entire row/s with null/s
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp.salary.value_counts(dropna=False)  # findout nulls and dupli
# Out:
# 56000     2
# 70000     1
# 50000     1
# 84000     1
# 90000     1
# 100000    1
# Name: salary, dtype: int64

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      NaN   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
books = pd.read_csv("https://raw.githubusercontent.com/realpython/python-data-cleaning/master/Datasets/BL-Flickr-Images-Book.csv")

# %%
books
# Out:
#       Identifier                                  Edition Statement  \
# 0            206                                                NaN
# 1            216                                                NaN
# 2            218                                                NaN
# 3            472                                                NaN
# 4            480                       A new edition, revised, etc.
# 5            481                      Fourth edition, revised, etc.
# 6            519                                                NaN
# 7            667                                                NaN
# 8            874                                                NaN
# 9           1143                                                NaN
# 10          1280                                                NaN
# 11          1808                                                NaN
# 12          1905                                                NaN
# ...

# %%
books.count()
# Out:
# Identifier                8287
# Edition Statement          773
# Place of Publication      8287
# Date of Publication       8106
# Publisher                 4092
# Title                     8287
# Author                    6509
# Contributors              8287
# Corporate Author             0
# Corporate Contributors       0
# Former owner                 1
# Engraver                     0
# Issuance type             8287
# Flickr URL                8287
# Shelfmarks                8287
# dtype: int64

# %%
books['Date of Publication'].isnull().sum()
# Out:
# 181

# %%
to_drop = ['Edition Statement',
...            'Corporate Author',
...            'Corporate Contributors',
...            'Former owner',
...            'Engraver',
...            'Contributors',
...            'Issuance type',
...            'Shelfmarks']

# %%
books
# Out:
#       Identifier                                  Edition Statement  \
# 0            206                                                NaN
# 1            216                                                NaN
# 2            218                                                NaN
# 3            472                                                NaN
# 4            480                       A new edition, revised, etc.
# 5            481                      Fourth edition, revised, etc.
# 6            519                                                NaN
# 7            667                                                NaN
# 8            874                                                NaN
# 9           1143                                                NaN
# 10          1280                                                NaN
# 11          1808                                                NaN
# 12          1905                                                NaN
# ...

# %%
books2 = books

# %%
books2
# Out:
#       Identifier                                  Edition Statement  \
# 0            206                                                NaN
# 1            216                                                NaN
# 2            218                                                NaN
# 3            472                                                NaN
# 4            480                       A new edition, revised, etc.
# 5            481                      Fourth edition, revised, etc.
# 6            519                                                NaN
# 7            667                                                NaN
# 8            874                                                NaN
# 9           1143                                                NaN
# 10          1280                                                NaN
# 11          1808                                                NaN
# 12          1905                                                NaN
# ...

# %%
books2.drop(to_drop,inplace=True,axis=1)

# %%
books2
# Out:
#       Identifier                               Place of Publication  \
# 0            206                                             London
# 1            216                           London; Virtue & Yorston
# 2            218                                             London
# 3            472                                             London
# 4            480                                             London
# 5            481                                             London
# 6            519                                             London
# 7            667                pp. 40. G. Bryan & Co: Oxford, 1898
# 8            874                                            London]
# 9           1143                                             London
# 10          1280                                           Coventry
# 11          1808                                        Christiania
# 12          1905                                            Firenze
# ...

# %%
books2.columns
# Out:
# Index(['Identifier', 'Place of Publication', 'Date of Publication',
#        'Publisher', 'Title', 'Author', 'Flickr URL'],
#       dtype='object')

# %%
books.columns
# Out:
# Index(['Identifier', 'Place of Publication', 'Date of Publication',
#        'Publisher', 'Title', 'Author', 'Flickr URL'],
#       dtype='object')

# %%
books.drop('Identifier',axis=1,inplace=True)

# %%
books.columns
# Out:
# Index(['Place of Publication', 'Date of Publication', 'Publisher', 'Title',
#        'Author', 'Flickr URL'],
#       dtype='object')

# %%
books['Date of Publication'].str.extract(r'^(\d{4})',expand=False)
# Out:
# 0       1879
# 1       1868
# 2       1869
# 3       1851
# 4       1857
# 5       1875
# 6       1872
# 7        NaN
# 8       1676
# 9       1679
# 10      1802
# 11      1859
# 12      1888
# 13      1839
# 14      1897
# 15      1865
# 16      1860
# 17      1873
# 18      1866
# 19      1899
# 20      1814
# 21      1820
# 22      1800
# 23      1847
# 24       NaN
# 25       NaN
# 26      1893
# 27      1805
# 28      1837
# 29      1896
#         ...
# 8257     NaN
# 8258    1896
# 8259     NaN
# 8260     NaN
# 8261    1750
# 8262    1879
# 8263     NaN
# 8264    1889
# 8265     NaN
# 8266    1876
# 8267     NaN
# 8268     NaN
# 8269    1708
# 8270     NaN
# 8271    1777
# 8272     NaN
# 8273    1866
# 8274    1862
# 8275    1894
# 8276    1868
# 8277    1882
# 8278    1883
# 8279    1898
# 8280    1811
# 8281    1867
# 8282    1838
# 8283    1831
# 8284     NaN
# 8285    1834
# 8286    1834
# Name: Date of Publication, Length: 8287, dtype: object

# %%
books['Publisher'].str.extract(r'(\w+)',expand=False)
# Out:
# 0                S
# 1           Virtue
# 2         Bradbury
# 3            James
# 4         Wertheim
# 5          William
# 6              The
# 7              NaN
# 8              NaN
# 9              NaN
# 10         Printed
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15               E
# 16             NaN
# 17             NaN
# 18             NaN
# 19               W
# 20             The
# 21               J
# 22               J
# 23           Punch
# 24        Bradbury
# 25        Bradbury
# 26             NaN
# 27               C
# 28               J
# 29             NaN
#            ...
# 8257           NaN
# 8258       Richard
# 8259           NaN
# 8260           NaN
# 8261       printed
# 8262           NaN
# 8263           NaN
# 8264           NaN
# 8265    Willoughby
# 8266             S
# 8267           NaN
# 8268           NaN
# 8269           NaN
# 8270           NaN
# 8271             J
# 8272           NaN
# ...

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      NaN   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
newcol = emp['manager id'].str.extract(r'(\d+)',expand=False)

# %%
newcol
# Out:
# 0    NaN
# 1    001
# 2    001
# 3    002
# 4    002
# 5    003
# 6    002
# Name: manager id, dtype: object

# %%
emp['salary'].value_counts(dropna=False)
# Out:
# 56000     2
# 70000     1
# 50000     1
# 84000     1
# 90000     1
# 100000    1
# Name: salary, dtype: int64

# %%
df1 = pd.DataFrame({'Date':['2018-01-01','2018-01-01','2018-01-02','2018-01-02'],'element':['max','min','max','min'],'value':[39,30,40,29]})

# %% [markdown]
# df1

# %%
df1
# Out:
#          Date element  value
# 0  2018-01-01     max     39
# 1  2018-01-01     min     30
# 2  2018-01-02     max     40
# 3  2018-01-02     min     29

# %%
df1.pivot(index='Date',columns='element',values='value')
#df1.pivot(columns='element',values='value')
# Out:
# element     max  min
# Date
# 2018-01-01   39   30
# 2018-01-02   40   29

# %%
df1.pivot_table(values='value',index='Date',columns='element',aggfunc=np.mean)
# Out:
# element     max  min
# Date
# 2018-01-01   39   30
# 2018-01-02   40   29

# %%
df2 = pd.pivot_table(df1,index='Date',columns='element',values='value')

# %%
df2
# Out:
# element     max  min
# Date
# 2018-01-01   39   30
# 2018-01-02   40   29

# %%
df2.reset_index(inplace=True)

# %%
df2
# Out:
# element        Date  max  min
# 0        2018-01-01   39   30
# 1        2018-01-02   40   29

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      NaN   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp_s = emp.stack()

# %%
emp_s
# Out:
# 0  Unnamed: 0                    0
#    dno                          10
#    employee id             ind-001
#    fullname           Abdul Rehman
#    position                    CSO
#    salary                   100000
#    department id                 1
# 1  Unnamed: 0                    1
#    dno                          20
#    employee id             ind-002
#    fullname              M. Yousuf
#    salary                    90000
#    manager id              ind-001
#    department id                 1
# 2  Unnamed: 0                    2
#    dno                          30
#    employee id             ind-003
#    fullname         Joseph D'Souza
#    position                    CVO
#    salary                    84000
#    manager id              ind-001
#    department id                 1
# 3  Unnamed: 0                    3
#    dno                          40
#    employee id             ind-004
#    fullname         Mahesh Kalmadi
#    position                    CWO
# ...

# %%
emp_s.unstack()
# Out:
#   Unnamed: 0 dno employee id        fullname position  salary manager id  \
# 0          0  10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1          1  20     ind-002       M. Yousuf      NaN   90000    ind-001
# 2          2  30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3          3  40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4          4  50      us-001  Jogender Singh      STO   56000    ind-002
# 5          5  60      us-002     Syed Mannan      SPO   56000    ind-003
# 6          6  70     dub-001            John      CTO   50000    ind-002
#
#   department id
# 0             1
# 1             1
# 2             1
# 3             2
# 4             2
# 5             3
# 6             0

# %%
import pandas as pd

# %%
emp = pd.read_csv("d:/datasets/employee.csv",encoding='utf-8')

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp.drop(columns='Unnamed: 0',axis=1,inplace=True)

# %%
emp.columns
# Out:
# Index(['dno', 'employee id', 'fullname', 'position', 'salary', 'manager id',
#        'department id'],
#       dtype='object')

# %%
emp
# Out:
#    dno employee id        fullname position  salary manager id  department id
# 0   10     ind-001    Abdul Rehman      CSO  100000        NaN              1
# 1   20     ind-002       M. Yousuf      CTO   90000    ind-001              1
# 2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001              1
# 3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002              2
# 4   50      us-001  Jogender Singh      STO   56000    ind-002              2
# 5   60      us-002     Syed Mannan      SPO   56000    ind-003              3
# 6   70     dub-001            John      CTO   50000    ind-002              0

# %%
gender = ['M','M',"F","M","M","F","M"]
emp['gender'] = gender

# %%
emp
# Out:
#    dno employee id        fullname position  salary manager id  department id  \
# 0   10     ind-001    Abdul Rehman      CSO  100000        NaN              1
# 1   20     ind-002       M. Yousuf      CTO   90000    ind-001              1
# 2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001              1
# 3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002              2
# 4   50      us-001  Jogender Singh      STO   56000    ind-002              2
# 5   60      us-002     Syed Mannan      SPO   56000    ind-003              3
# 6   70     dub-001            John      CTO   50000    ind-002              0
#
#   gender
# 0      M
# 1      M
# 2      F
# 3      M
# 4      M
# 5      F
# 6      M

# %%
emp.drop("gender",axis=1,inplace=True)

# %%
emp
# Out:
#    dno employee id        fullname position  salary manager id  department id
# 0   10     ind-001    Abdul Rehman      CSO  100000        NaN              1
# 1   20     ind-002       M. Yousuf      CTO   90000    ind-001              1
# 2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001              1
# 3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002              2
# 4   50      us-001  Jogender Singh      STO   56000    ind-002              2
# 5   60      us-002     Syed Mannan      SPO   56000    ind-003              3
# 6   70     dub-001            John      CTO   50000    ind-002              0

# %%
emp['empid_isalnum'] = map(lambda x: x.isalnum(), emp['employee id'])

# %%
emp
# Out:
#    dno employee id        fullname position  salary manager id  department id  \
# 0   10     ind-001    Abdul Rehman      CSO  100000        NaN              1
# 1   20     ind-002       M. Yousuf      CTO   90000    ind-001              1
# 2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001              1
# 3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002              2
# 4   50      us-001  Jogender Singh      STO   56000    ind-002              2
# 5   60      us-002     Syed Mannan      SPO   56000    ind-003              3
# 6   70     dub-001            John      CTO   50000    ind-002              0
#
#                         empid_isalnum
# 0  <map object at 0x0000000008573D68>
# 1  <map object at 0x0000000008573D68>
# 2  <map object at 0x0000000008573D68>
# 3  <map object at 0x0000000008573D68>
# 4  <map object at 0x0000000008573D68>
# 5  <map object at 0x0000000008573D68>
# 6  <map object at 0x0000000008573D68>

# %%
set(emp['empid_isalnum'])
# Out:
# {<map at 0x8573d68>}

# %%
def it(it):
    for x in it:
        print (x)
    print ('')

# %%
it(emp['empid_isalnum'])

# %%
emp.drop('empid_isalnum',inplace=True,axis=1)

# %%
emp
# Out:
#    dno employee id        fullname position  salary manager id  department id
# 0   10     ind-001    Abdul Rehman      CSO  100000        NaN              1
# 1   20     ind-002       M. Yousuf      CTO   90000    ind-001              1
# 2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001              1
# 3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002              2
# 4   50      us-001  Jogender Singh      STO   56000    ind-002              2
# 5   60      us-002     Syed Mannan      SPO   56000    ind-003              3
# 6   70     dub-001            John      CTO   50000    ind-002              0

# %%
airq = pd.read_csv('d:/datasets/airq.csv')

# %%
airq
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2    NaN      NaN  14.3    56      5    5

# %%
airq_melt = pd.melt(airq,id_vars = ['Month','Day'])

# %%
airq_melt
# Out:
#     Month  Day variable  value
# 0       5    1    Ozone   41.0
# 1       5    2    Ozone   36.0
# 2       5    5    Ozone    NaN
# 3       5    1  Solar.R  190.0
# 4       5    2  Solar.R  118.0
# 5       5    5  Solar.R    NaN
# 6       5    1     Wind    7.4
# 7       5    2     Wind    8.0
# 8       5    5     Wind   14.3
# 9       5    1     Temp   67.0
# 10      5    2     Temp   72.0
# 11      5    5     Temp   56.0

# %%
airq_melt.pivot(columns='variable',values='value')
# Out:
# variable  Ozone  Solar.R  Temp  Wind
# 0          41.0      NaN   NaN   NaN
# 1          36.0      NaN   NaN   NaN
# 2           NaN      NaN   NaN   NaN
# 3           NaN    190.0   NaN   NaN
# 4           NaN    118.0   NaN   NaN
# 5           NaN      NaN   NaN   NaN
# 6           NaN      NaN   NaN   7.4
# 7           NaN      NaN   NaN   8.0
# 8           NaN      NaN   NaN  14.3
# 9           NaN      NaN  67.0   NaN
# 10          NaN      NaN  72.0   NaN
# 11          NaN      NaN  56.0   NaN

# %%
temp = {"date":["2018-01-01","2018-01-01","2018-01-02","2018-01-02"],"variable":["tmax","tmin","tmax","tmin"],"value":[40,30,42,32]}

# %%
temp
# Out:
# {'date': ['2018-01-01', '2018-01-01', '2018-01-02', '2018-01-02'],
#  'variable': ['tmax', 'tmin', 'tmax', 'tmin'],
#  'value': [40, 30, 42, 32]}

# %%
tempdf = pd.DataFrame(temp)

# %%
tempdf
# Out:
#          date variable  value
# 0  2018-01-01     tmax     40
# 1  2018-01-01     tmin     30
# 2  2018-01-02     tmax     42
# 3  2018-01-02     tmin     32

# %%
tempdf.set_index("date")
# Out:
#            variable  value
# date
# 2018-01-01     tmax     40
# 2018-01-01     tmin     30
# 2018-01-02     tmax     42
# 2018-01-02     tmin     32

# %%
tempdf2 = tempdf.pivot(index="date",columns="variable",values="value")

# %%
tempdf2
# Out:
# variable    tmax  tmin
# date
# 2018-01-01    40    30
# 2018-01-02    42    32

# %%
temp2 = {"date":["2018-01-01","2018-01-01","2018-01-02","2018-01-02","2018-01-02"],"variable":["tmax","tmin","tmax","tmin","tmin"],"value":[40,30,42,32,18]}

# %% [markdown]
# temp2

# %%
temp2
# Out:
# {'date': ['2018-01-01',
#   '2018-01-01',
#   '2018-01-02',
#   '2018-01-02',
#   '2018-01-02'],
#  'variable': ['tmax', 'tmin', 'tmax', 'tmin', 'tmin'],
#  'value': [40, 30, 42, 32, 18]}

# %%
temp2df = pd.DataFrame(temp2)

# %%
temp2df
# Out:
#          date variable  value
# 0  2018-01-01     tmax     40
# 1  2018-01-01     tmin     30
# 2  2018-01-02     tmax     42
# 3  2018-01-02     tmin     32
# 4  2018-01-02     tmin     18

# %%
import numpy as np

# %%
temp2df_ptab = temp2df.pivot_table(index="date",columns="variable",values="value",aggfunc=np.sum)   ## duplicate rows  error

# %%
temp2df_ptab
# Out:
# variable    tmax  tmin
# date
# 2018-01-01    40    30
# 2018-01-02    42    50

# %%
cust = {"name":["A","B","C"], "city":["Hyd","Pune","Mum"],"gen_age":["M30","M25","F25"]}

# %%
cust
# Out:
# {'name': ['A', 'B', 'C'],
#  'city': ['Hyd', 'Pune', 'Mum'],
#  'gen_age': ['M30', 'M25', 'F25']}

# %%
custdf = pd.DataFrame(cust)

# %%
custdf
# Out:
#   name  city gen_age
# 0    A   Hyd     M30
# 1    B  Pune     M25
# 2    C   Mum     F25

# %%
custdf["Gender"]=custdf.gen_age.str[0]

# %%
custdf
# Out:
#   name  city gen_age Gender
# 0    A   Hyd     M30      M
# 1    B  Pune     M25      M
# 2    C   Mum     F25      F

# %%
custdf["age"]=custdf.gen_age.str[0:2]

# %%
custdf
# Out:
#   name  city gen_age Gender age
# 0    A   Hyd     M30      M  30
# 1    B  Pune     M25      M  25
# 2    C   Mum     F25      F  25

# %%
rating = [1,2,3]

# %%
ratingdf = pd.DataFrame(rating)

# %%
ratingdf
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
custnew = pd.concat([custdf,ratingdf],axis=1)

# %%
custnew
# Out:
#   name  city gen_age Gender age  0
# 0    A   Hyd     M30      M  30  1
# 1    B  Pune     M25      M  25  2
# 2    C   Mum     F25      F  25  3

# %%
custdf2 = custdf

# %%
custdf2
# Out:
#   name  city gen_age Gender age
# 0    A   Hyd     M30      M  30
# 1    B  Pune     M25      M  25
# 2    C   Mum     F25      F  25

# %%
custdf2_new = custdf.copy()

# %%
custdf2_new
# Out:
#   name  city gen_age Gender age
# 0    A   Hyd     M30      M  30
# 1    B  Pune     M25      M  25
# 2    C   Mum     F25      F  25

# %%
custdf2_new.drop('age',axis=1,inplace=True)

# %%
custdf2_new
# Out:
#   name  city gen_age Gender
# 0    A   Hyd     M30      M
# 1    B  Pune     M25      M
# 2    C   Mum     F25      F

# %%
custdf2_new=custnew.copy()

# %%
custdf2_new
# Out:
#   name  city gen_age Gender age  0
# 0    A   Hyd     M30      M  30  1
# 1    B  Pune     M25      M  25  2
# 2    C   Mum     F25      F  25  3

# %%
custnew2=custnew.copy()

# %%
custnew2
# Out:
#   name  city gen_age Gender age  0
# 0    A   Hyd     M30      M  30  1
# 1    B  Pune     M25      M  25  2
# 2    C   Mum     F25      F  25  3

# %%
custnew3=custnew2.copy()

# %%
custnew3
# Out:
#   name  city gen_age Gender age  0
# 0    A   Hyd     M30      M  30  1
# 1    B  Pune     M25      M  25  2
# 2    C   Mum     F25      F  25  3

# %%
custnew["New_Col"]=[1,2,3]

# %%
custnew
# Out:
#   name  city gen_age Gender age  0  New_Col
# 0    A   Hyd     M30      M  30  1        1
# 1    B  Pune     M25      M  25  2        2
# 2    C   Mum     F25      F  25  3        3

# %%
custdf
# Out:
#   name  city gen_age Gender age
# 0    A   Hyd     M30      M  30
# 1    B  Pune     M25      M  25
# 2    C   Mum     F25      F  25

# %%
custdf.T
# Out:
#            0     1    2
# name       A     B    C
# city     Hyd  Pune  Mum
# gen_age  M30   M25  F25
# Gender     M     M    F
# age       30    25   25

# %%
custnew3
# Out:
#   name  city gen_age Gender age  0
# 0    A   Hyd     M30      M  30  1
# 1    B  Pune     M25      M  25  2
# 2    C   Mum     F25      F  25  3

# %%
custnew3.T
# Out:
#            0     1    2
# name       A     B    C
# city     Hyd  Pune  Mum
# gen_age  M30   M25  F25
# Gender     M     M    F
# age       30    25   25
# 0          1     2    3

# %%
cust_transpose = custnew3.T    # Transposing a Dataframe

# %%
cust_transpose
# Out:
#            0     1    2
# name       A     B    C
# city     Hyd  Pune  Mum
# gen_age  M30   M25  F25
# Gender     M     M    F
# age       30    25   25
# 0          1     2    3

# %%
# initializing string  
str = "geeksforgeeks"
  
# encoding string  
str_enc = str.encode('base64', 'strict') 
  
# printing the encoded string 
print ("The encoded string in base64 format is : ")
print (str_enc )
  
# printing the original decoded string  
print ("The decoded string is : ")
print (str_enc.decode('base64', 'strict') )
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-66-514ac852ff89> in <module>()
#       3
#       4 # encoding string
# ----> 5 str_enc = str.encode('base64', 'strict')
#       6
#       7 # printing the encoded string
#
# LookupError: 'base64' is not a text encoding; use codecs.encode() to handle arbitrary codecs

# %%
import json      #Python JSON to dict    #You can parse a JSON string using json.loads() method. The method returns a dictionary.

person = '{"name": "Bob", "languages": ["English", "Fench"]}'
person_dict = json.loads(person)
print( person_dict)
# Out:
# {'name': 'Bob', 'languages': ['English', 'Fench']}

# %%
import json     # Writing JSON to a file # To write JSON to a file in Python, we can use json.dump() method.

person_dict = {"name": "Bob",
"languages": ["English", "Fench"],
"married": True,
"age": 32
}

with open('C:/Users/admin/Desktop/person.txt', 'w') as json_file:
    print(json.dump(person_dict, json_file))
# Out:
# None

# %%
json_file
# Out:
# <_io.TextIOWrapper name='C:/Users/admin/Desktop/person.txt' mode='w' encoding='cp1252'>

# %%
import json                # Python pretty print JSON

person_string = '{"name": "Bob", "languages": "English", "numbers": [2, 1.6, null]}'

# Getting dictionary
person_dict = json.loads(person_string)

# Pretty Printing JSON string back  #To analyze and debug JSON data, we may need to print it in a more readable format.
# This can be done by passing additional parameters indent and sort_keys to json.dumps() and json.dump() method.
print(json.dumps(person_dict, indent = 4, sort_keys=True))
# Out:
# {
#     "languages": "English",
#     "name": "Bob",
#     "numbers": [
#         2,
#         1.6,
#         null
#     ]
# }

# %%
product_det ='{"itemid":1001,"Description":"GPU-LX001","Qty":1000,"Price":5000.00,"Taxable":"True"}'

# %%
product_det
# Out:
# '{"itemid":1001,"Description":"GPU-LX001","Qty":1000,"Price":5000.00,"Taxable":"True"}'

# %%
# Convert from JSON to Python
import json

# some JSON:
x = '{ "name":"John", "age":30, "city":"New York"}'

# parse x:
y = json.loads(x)

# the result is a Python dictionary:
print(y["age"])
# Out:
# 30

# %%
# Convert from Python to JSON 
import json
# a Python object (dict):
x = {
  "name": "John",
  "age": 30,
  "city": "New York"
}
# convert into JSON:
y = json.dumps(x)

# the result is a JSON string:
print(y)
# Out:
# {"name": "John", "age": 30, "city": "New York"}

# %%
# Convert Python objects into JSON strings
import json

print(json.dumps({"name": "John", "age": 30}))
print(json.dumps(["apple", "bananas"]))
print(json.dumps(("apple", "bananas")))
print(json.dumps("hello"))
print(json.dumps(42))
print(json.dumps(31.76))
print(json.dumps(True))
print(json.dumps(False))
print(json.dumps(None))
# Out:
# {"name": "John", "age": 30}
# ["apple", "bananas"]
# ["apple", "bananas"]
# "hello"
# 42
# 31.76
# true
# false
# null

# %%
# Convert a Python object Containing all the legal data types 
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}

# convert into JSON:
y = json.dumps(x)

# the result is a JSON string:
print(y)
# Out:
# {"name": "John", "age": 30, "married": true, "divorced": false, "children": ["Ann", "Billy"], "pets": null, "cars": [{"model": "BMW 230", "mpg": 27.5}, {"model": "Ford Edge", "mpg": 24.1}]}

# %%
# Use the indent parameter to define the numbers of indents
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}

# use four indents to make it easier to read the result:
print(json.dumps(x, indent=4))
# Out:
# {
#     "name": "John",
#     "age": 30,
#     "married": true,
#     "divorced": false,
#     "children": [
#         "Ann",
#         "Billy"
#     ],
#     "pets": null,
#     "cars": [
#         {
#             "model": "BMW 230",
#             "mpg": 27.5
#         },
#         {
#             "model": "Ford Edge",
#             "mpg": 24.1
#         }
#     ]
# }

# %%
# Use the seperators parameter to change the default separator 
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}
# use . and a space to separate objects, and a space, a = and a space to separate keys from their values:
print(json.dumps(x, indent=4, separators=(". ", " = ")))
# Out:
# {
#     "name" = "John".
#     "age" = 30.
#     "married" = true.
#     "divorced" = false.
#     "children" = [
#         "Ann".
#         "Billy"
#     ].
#     "pets" = null.
#     "cars" = [
#         {
#             "model" = "BMW 230".
#             "mpg" = 27.5
#         }.
#         {
#             "model" = "Ford Edge".
#             "mpg" = 24.1
#         }
#     ]
# }

# %%
# Use the sort_keys parameter to specify if the result should be sorted or not
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}
# sort the result alphabetically by keys:
print(json.dumps(x, indent=4, sort_keys=True))
# Out:
# {
#     "age": 30,
#     "cars": [
#         {
#             "model": "BMW 230",
#             "mpg": 27.5
#         },
#         {
#             "model": "Ford Edge",
#             "mpg": 24.1
#         }
#     ],
#     "children": [
#         "Ann",
#         "Billy"
#     ],
#     "divorced": false,
#     "married": true,
#     "name": "John",
#     "pets": null
# }

# %%
type(product_det)
# Out:
# str

# %%
product_obj = json.loads(product_det)

# %%
type(product_obj)
# Out:
# dict

# %%
product_obj_s = json.dumps(product_obj)   # from dict to string

# %%
type(product_obj_s)
# Out:
# str

# %%
emp = {}
emp["empid"] = 1001
emp["fullname"] = "Abc xyz"
emp["salary"] = 50000.00
emp["skill"] = "Data Analytics"
empfile = open("employee.txt","w")
json.dump(emp,empfile)
empfile.close()

# %%
# !cat employee.txt
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.python.org/~guido/'
r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
html_doc = r.text

# %%
html_doc
# Out:
# '<HTML>\n\n<HEAD>\n<TITLE>Guido\'s Personal Home Page</TITLE>\n</HEAD>\n\n<BODY BGCOLOR="#FFFFFF" TEXT="#000000">\n\n<H1>\n<a href="pics.html"><img border="0" src="images/IMG_2192.jpg"></a>\nGuido van Rossum - Personal Home Page\n<a href="pics.html"><img border=0 width=270 height=216 src="images/guido-headshot-2019.jpg"></a>\n</H1>\n\n<P><A\nHREF="http://www.washingtonpost.com/wp-srv/business/longterm/microsoft/stories/1998/raymond120398.htm" \n><i>"Gawky and proud of it."</i></A>\n\n\n<H3><a href="images/df20000406.jpg" >Who I Am</a></H3>\n\n<p>Read\nmy <a href="http://neopythonic.blogspot.com/2016/04/kings-day-speech.html">"King\'s\nDay Speech"</a> for some inspiration.\n\n<P>I am the author of the <A HREF="http://www.python.org" >Python</A>\nprogramming language.  See also my <A HREF="Resume.html">resume</A>\nand my <A HREF="Publications.html">publications list</A>, a <A\nHREF="bio.html" >brief bio</A>, assorted <a\nhref="http://legacy.python.org/doc/essays/">writings</a>, <a\nhre
# ...

# %%
soup = BeautifulSoup(html_doc,'html.parser')

# %%
soup
# Out:
# <html>
# <head>
# <title>Guido's Personal Home Page</title>
# </head>
# <body bgcolor="#FFFFFF" text="#000000">
# <h1>
# <a href="pics.html"><img border="0" src="images/IMG_2192.jpg"/></a>
# Guido van Rossum - Personal Home Page
# <a href="pics.html"><img border="0" height="216" src="images/guido-headshot-2019.jpg" width="270"/></a>
# </h1>
# <p><a href="http://www.washingtonpost.com/wp-srv/business/longterm/microsoft/stories/1998/raymond120398.htm"><i>"Gawky and proud of it."</i></a>
# <h3><a href="images/df20000406.jpg">Who I Am</a></h3>
# <p>Read
# my <a href="http://neopythonic.blogspot.com/2016/04/kings-day-speech.html">"King's
# Day Speech"</a> for some inspiration.
#
# <p>I am the author of the <a href="http://www.python.org">Python</a>
# programming language.  See also my <a href="Resume.html">resume</a>
# ...

# %%
contents = r.content

# %%
contents
# Out:
# b'<HTML>\n\n<HEAD>\n<TITLE>Guido\'s Personal Home Page</TITLE>\n</HEAD>\n\n<BODY BGCOLOR="#FFFFFF" TEXT="#000000">\n\n<H1>\n<a href="pics.html"><img border="0" src="images/IMG_2192.jpg"></a>\nGuido van Rossum - Personal Home Page\n<a href="pics.html"><img border=0 width=270 height=216 src="images/guido-headshot-2019.jpg"></a>\n</H1>\n\n<P><A\nHREF="http://www.washingtonpost.com/wp-srv/business/longterm/microsoft/stories/1998/raymond120398.htm" \n><i>"Gawky and proud of it."</i></A>\n\n\n<H3><a href="images/df20000406.jpg" >Who I Am</a></H3>\n\n<p>Read\nmy <a href="http://neopythonic.blogspot.com/2016/04/kings-day-speech.html">"King\'s\nDay Speech"</a> for some inspiration.\n\n<P>I am the author of the <A HREF="http://www.python.org" >Python</A>\nprogramming language.  See also my <A HREF="Resume.html">resume</A>\nand my <A HREF="Publications.html">publications list</A>, a <A\nHREF="bio.html" >brief bio</A>, assorted <a\nhref="http://legacy.python.org/doc/essays/">writings</a>, <a\nhr
# ...

# %%
soup.title()
# Out:
# []

# %%
soup.get_text()
# Out:
# '\n\nGuido\'s Personal Home Page\n\n\n\n\nGuido van Rossum - Personal Home Page\n\n\n"Gawky and proud of it."\nWho I Am\nRead\nmy "King\'s\nDay Speech" for some inspiration.\n\nI am the author of the Python\nprogramming language.  See also my resume\nand my publications list, a brief bio, assorted writings, presentations and interviews (all about Python), some\npictures of me,\nmy new blog, and\nmy old\nblog on Artima.com.  I am\n@gvanrossum on Twitter.\n\nI am retired, working on personal projects (and maybe a book).\nI have worked for Dropbox, Google, Elemental Security, Zope\nCorporation, BeOpen.com, CNRI, CWI, and SARA.  (See\nmy resume.)  I created Python while at CWI.\n\nHow to Reach Me\nYou can send email for me to guido (at) python.org.\nI read everything sent there, but I receive too much email to respond\nto everything.\n\nMy Name\nMy name often poses difficulties for Americans.\n\nPronunciation: in Dutch, the "G" in Guido is a hard G,\npronounced roughly like the "ch" in S
# ...

# %%
a_tags = soup.find_all('a')

# %%
a_tags
# Out:
# [<a href="pics.html"><img border="0" src="images/IMG_2192.jpg"/></a>,
#  <a href="pics.html"><img border="0" height="216" src="images/guido-headshot-2019.jpg" width="270"/></a>,
#  <a href="http://www.washingtonpost.com/wp-srv/business/longterm/microsoft/stories/1998/raymond120398.htm"><i>"Gawky and proud of it."</i></a>,
#  <a href="images/df20000406.jpg">Who I Am</a>,
#  <a href="http://neopythonic.blogspot.com/2016/04/kings-day-speech.html">"King's
#  Day Speech"</a>,
#  <a href="http://www.python.org">Python</a>,
#  <a href="Resume.html">resume</a>,
#  <a href="Publications.html">publications list</a>,
#  <a href="bio.html">brief bio</a>,
#  <a href="http://legacy.python.org/doc/essays/">writings</a>,
#  <a href="http://legacy.python.org/doc/essays/ppt/">presentations</a>,
#  <a href="interviews.html">interviews</a>,
#  <a href="pics.html">pictures of me</a>,
#  <a href="http://neopythonic.blogspot.com">my new blog</a>,
# ...

# %%
for link in a_tags:
    print (link.get('href'))
# Out:
# pics.html
# pics.html
# http://www.washingtonpost.com/wp-srv/business/longterm/microsoft/stories/1998/raymond120398.htm
# images/df20000406.jpg
# http://neopythonic.blogspot.com/2016/04/kings-day-speech.html
# http://www.python.org
# Resume.html
# Publications.html
# bio.html
# http://legacy.python.org/doc/essays/
# http://legacy.python.org/doc/essays/ppt/
# interviews.html
# pics.html
# http://neopythonic.blogspot.com
# http://www.artima.com/weblogs/index.jsp?blogger=12088
# https://twitter.com/gvanrossum
# Resume.html
# guido.au
# http://legacy.python.org/doc/essays/
# images/license.jpg
# http://www.cnpbagwell.com/audio-faq
# http://sox.sourceforge.net/
# images/internetdog.gif

# %%
ms_url = "https://en.wikipedia.org/wiki/Microsoft"

# %%
ms_url
# Out:
# 'https://en.wikipedia.org/wiki/Microsoft'

# %%
ms_r = requests.get(ms_url)

# %%
ms_r
# Out:
# <Response [200]>

# %%
ms_text = ms_r.text

# %%
ms_content = ms_r.content

# %%
ms_text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Microsoft - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"Xm77ZQpAIDEAACam2uoAAABT","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Microsoft","wgTitle":"Microsoft","wgCurRevisionId":945788244,"wgRevisionId":945788244,"wgArticleId":19001,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Webarchive template wayback links","Wikipedia indefinitely semi-protected pages","Wikipedi
# ...

# %%
ms_soup = BeautifulSoup(ms_content,'html.parser')

# %%
ms_soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Microsoft - Wikipedia</title>
# ...

# %%
print(ms_soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Microsoft - Wikipedia</title>
# ...

# %%
list(ms_soup.children)
# Out:
# ['html', '\n', <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#  <meta charset="utf-8"/>
#  <title>Microsoft - Wikipedia</title>
# ...

# %%
a_tags = ms_soup.find_all('a')

# %%
a_tags
# Out:
# [<a id="top"></a>,
#  <a href="/wiki/Wikipedia:Protection_policy#semi" title="This article is semi-protected."><img alt="Page semi-protected" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
# ...

# %%
for link in a_tags:
    print (link.get('href'))
# Out:
# None
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #p-search
# /wiki/File:Microsoft_logo_(2012).svg
# /wiki/File:Building92microsoft.jpg
# /wiki/Microsoft_Redmond_campus
# /wiki/List_of_legal_entity_types_by_country
# /wiki/Public_company
# /wiki/Ticker_symbol
# /wiki/NASDAQ
# https://www.nasdaq.com/symbol/msft
# /wiki/NASDAQ-100
# /wiki/Dow_Jones_Industrial_Average
# /wiki/S%26P_100
# /wiki/S%26P_500
# /wiki/International_Securities_Identification_Number
# https://tools.wmflabs.org/isin/?language=en&isin=US5949181045
# /wiki/Software_development
# /wiki/Computer_hardware
# /wiki/Consumer_electronics
# /wiki/Social_networking_service
# /wiki/Cloud_computing
# /wiki/Video_game_industry
# /wiki/Internet
# /wiki/Corporate_venture_capital
# /wiki/Traf-O-Data
# /wiki/Albuquerque,_New_Mexico
# /wiki/Bill_Gates
# /wiki/Paul_Allen
# /wiki/Microsoft_Redmond_campus
# /wiki/Redmond,_Washington
# /wiki/John_W._Thompson
# /wiki/Chairman
# /wiki/Satya_Nadella
# ...

# %%
page = requests.get("http://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168")
soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find(id="seven-day-forecast")
forecast_items = seven_day.find_all(class_="tombstone-container")
tonight = forecast_items[0]
print(tonight.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   Overnight
#   <br/>
#   <br/>
#  </p>
#  <p>
#   <img alt="Overnight: Showers likely.  Mostly cloudy, with a low around 45. Calm wind becoming east southeast around 6 mph.  Chance of precipitation is 70%. New precipitation amounts of less than a tenth of an inch possible. " class="forecast-icon" src="newimages/medium/nshra70.png" title="Overnight: Showers likely.  Mostly cloudy, with a low around 45. Calm wind becoming east southeast around 6 mph.  Chance of precipitation is 70%. New precipitation amounts of less than a tenth of an inch possible. "/>
#  </p>
#  <p class="short-desc">
#   Showers
#   <br/>
#   Likely
#  </p>
#  <p class="temp temp-low">
#   Low: 45 °F
#  </p>
# </div>

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js">
# <head>
# <!-- Meta -->
# <meta content="width=device-width" name="viewport"/>
# <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/><title>National Weather Service</title><meta content="National Weather Service" name="DC.title"><meta content="NOAA National Weather Service National Weather Service" name="DC.description"/><meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/><meta content="" name="DC.date.created" scheme="ISO8601"/><meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/><meta content="weather, National Weather Service" name="DC.keywords"/><meta content="NOAA's National Weather Service" name="DC.publisher"/><meta content="National Weather Service" name="DC.contributor"/><meta content="http://www.weather.gov/disclaimer.php" name="DC.rights"/><meta content="General" name="rating"/><meta content="index,follow" name="robots"/>
# <!-- Icons -->
# ...

# %%
period = tonight.find(class_="period-name").get_text()

# %%
short_desc = tonight.find(class_="short-desc").get_text()

# %%
temp = tonight.find(class_="temp").get_text()

print(period)
print(short_desc)
print(temp)
# Out:
# Overnight
# ShowersLikely
# Low: 45 °F

# %%
import requests

# %%
result = requests.get("https://www.magicbricks.com/cc")

# %%
result
# Out:
# <Response [404]>

# %%
from bs4 import BeautifulSoup

# %%
result.text
# Out:
# "<html><head><title>SERVER - Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1><center>Oops. some thing went wrong. please use browser's back button to go back to previous page</center></h1></body></html>"

# %%
soup = BeautifulSoup(result.text, 'html.parser')

# %%
soup
# Out:
# <html><head><title>SERVER - Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1><center>Oops. some thing went wrong. please use browser's back button to go back to previous page</center></h1></body></html>

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    SERVER - Error report
#   </title>
#   <style>
#    <!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}-->
#   </style>
#  </head>
#  <body>
#   <h1>
#    <center>
#     Oops. some thing went wrong. please use browser's back button to go back to previous page
#    </center>
#   </h1>
#  </body>
# </html>

# %%
# Import package
import requests

# Assign URL to variable: url
url = "https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exintro=&titles=india"

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Decode the JSON data into a dictionary: json_data
json_data = r.json()

print (json_data)

# Print the Wikipedia page extract
#pizza_extract = json_data['query']['pages']['24768']['extract']
#print(pizza_extract)
# Out:
# {'batchcomplete': '', 'warnings': {'extracts': {'*': 'HTML may be malformed and/or unbalanced and may omit inline images. Use at your own risk. Known problems are listed at https://www.mediawiki.org/wiki/Extension:TextExtracts#Caveats.'}}, 'query': {'normalized': [{'from': 'india', 'to': 'India'}], 'pages': {'14533': {'pageid': 14533, 'ns': 0, 'title': 'India', 'extract': '<p class="mw-empty-elt">\n</p>\n\n<p class="mw-empty-elt">\n</p>\n<p><b>India</b> (Hindi: <i lang="hi-Latn" title="ISO 15919 Indic (Hindi language) transliteration">Bhārat</i>), officially the <b>Republic of India</b> (Hindi: <i lang="hi-Latn" title="ISO 15919 Indic (Hindi language) transliteration">Bhārat Gaṇarājya</i>), is a country in South Asia. It is the seventh-largest country by area, the second-most populous country, and the most populous democracy in the world. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pak
# ...

# %%
topic = input("Enter your choice of Topic:")
url = "https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exintro=&titles={}".format(topic)

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Decode the JSON data into a dictionary: json_data
json_data = r.json()
json_data
