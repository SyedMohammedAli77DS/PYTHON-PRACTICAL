# %%
import pandas as pd

# %%
print (pd.__version__)
import sys
# Out:
# 0.23.0

# %%
sys.version
# Out:
# '3.6.5 |Anaconda, Inc.| (default, Mar 29 2018, 13:32:41) [MSC v.1900 64 bit (AMD64)]'

# %%
import numpy as np
import pandas as pd
path = 'd:/datasets/kyphosis.csv'

# %%
kyposis = pd.read_csv('d:/datasets/kyphosis.csv')

# %%
import pandas as pd

# %%
Book = pd.read_csv('d:/Datasets/Book.csv')

# %%
Book

# %%
import pandas as pd

# %%
employee = pd.read_csv('d:/Datasets/employee.csv')

# %%
import pandas as pd
titanic = pd.read_csv('d:/Datasets/titanic.csv')

# %%
emp = pd.read_csv('d:/datasets/employee.csv')

# %%
emp
# Out:
#   employee id        fullname position  salary manager id  department id
# 0     ind-001    Abdul Rehman      CSO  100000        NaN              1
# 1     ind-002       M. Yousuf      CTO   90000    ind-001              1
# 2     ind-003  Joseph D'Souza      CVO   84000    ind-001              1
# 3     ind-004  Mahesh Kalmadi      CWO   70000    ind-002              2
# 4      us-001  Jogender Singh      STO   56000    ind-002              2
# 5      us-002     Syed Mannan      SPO   56000    ind-003              3
# 6     dub-001            John      CTO   50000    ind-002              0

# %%
import pandas as pd
titanic = pd.read_csv('d:/Datasets/titanic.csv')

# %%
titanic
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch      fare  \
# 0             0         0       3    male  22.0      1      0    7.2500
# 1             1         1       1  female  38.0      1      0   71.2833
# 2             2         1       3  female  26.0      0      0    7.9250
# 3             3         1       1  female  35.0      1      0   53.1000
# 4             4         0       3    male  35.0      0      0    8.0500
# 5             5         0       3    male   NaN      0      0    8.4583
# 6             6         0       1    male  54.0      0      0   51.8625
# 7             7         0       3    male   2.0      3      1   21.0750
# 8             8         1       3  female  27.0      0      2   11.1333
# 9             9         1       2  female  14.0      1      0   30.0708
# 10           10         1       3  female   4.0      1      1   16.7000
# 11           11         1       1  female  58.0      0      0   26.5500
# ...

# %%
import pandas as pd
cars = pd.read_csv('d:/Datasets/cars.csv')

# %%
cars
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0           audi                  a4    1.8  1999    4    auto(l5)   f   18
# 1           audi                  a4    1.8  1999    4  manual(m5)   f   21
# 2           audi                  a4    2.0  2008    4  manual(m6)   f   20
# 3           audi                  a4    2.0  2008    4    auto(av)   f   21
# 4           audi                  a4    2.8  1999    6    auto(l5)   f   16
# 5           audi                  a4    2.8  1999    6  manual(m5)   f   18
# 6           audi                  a4    3.1  2008    6    auto(av)   f   18
# 7           audi          a4 quattro    1.8  1999    4  manual(m5)   4   18
# 8           audi          a4 quattro    1.8  1999    4    auto(l5)   4   16
# 9           audi          a4 quattro    2.0  2008    4  manual(m6)   4   20
# 10          audi          a4 quattro    2.0  2008    4    auto(s6)   4   19
# ...

# %%
import pandas as pd
income = pd.read_csv('d:/Datasets/income.csv')

# %%
income
# Out:
#             state  age  expenses  income  saving  grade diabetics  cars  \
# 0     Connecticut   36     34985   42660    7675      4   Healthy     1
# 1        Delaware   39     35984   43899    7915      8      Sick     1
# 2              DC   29     36272   44918    8646      3   Healthy     2
# 3         Florida   42     61640   72809   11169      9      Sick     4
# 4         Georgia   38     62422   72500   10078      3   Healthy     3
# 5          Hawaii   32     62980   73151   10171      4      Sick     3
# 6           Idaho   39     63511   73361    9850      9   Healthy     2
# 7        Illinois   25    127275  136825    9550      2      Sick     2
# 8         Indiana   57    128571  138216    9645      6      Sick     2
# 9            Iowa   46    129988  140168   10180     10   Healthy     3
# 10         Kansas   21     93419  103277    9858      4      Sick     2
# 11       Kentucky   39     57527   69173   11646      1   Healthy     4
# ...

# %%
import pandas as pd
kyphosis = pd.read_csv('d:/Datasets/kyphosis.csv')

# %%
kyphosis
# Out:
#    Kyphosis  Age  Number  Start
# 0    absent   71       3      5
# 1    absent  158       3     14
# 2   present  128       4      5
# 3    absent    2       5      1
# 4    absent    1       4     15
# 5    absent    1       2     16
# 6    absent   61       2     17
# 7    absent   37       3     16
# 8    absent  113       2     16
# 9   present   59       6     12
# 10  present   82       5     14
# 11   absent  148       3     16
# 12   absent   18       5      2
# 13   absent    1       4     12
# 14   absent  168       3     18
# 15   absent    1       3     16
# 16   absent   78       6     15
# 17   absent  175       5     13
# 18   absent   80       5     16
# 19   absent   27       4      9
# 20   absent   22       2     16
# 21  present  105       6      5
# 22  present   96       3     12
# 23   absent  131       2      3
# 24  present   15       7      2
# 25   absent    9       5     13
# 26   absent    8       3      6
# 27   absent  100       3     14
# ...

# %%
import pandas as pd
dept= pd.read_csv('d:/Datasets/department.csv')

# %%
dept
# Out:
#    Unnamed: 0  dno    dname       loc
# 0           0   10  finance       hyd
# 1           1   20       hr    mumbai
# 2           2   30       IT     delhi
# 3           3   40      Rnd  calcutta

# %%
dept.head()
# Out:
#    Unnamed: 0  dno    dname       loc
# 0           0   10  finance       hyd
# 1           1   20       hr    mumbai
# 2           2   30       IT     delhi
# 3           3   40      Rnd  calcutta

# %%
dept.head(2) # initial 2 records
# Out:
#    Unnamed: 0  dno    dname     loc
# 0           0   10  finance     hyd
# 1           1   20       hr  mumbai

# %%
dept.tail(2) # last 2 records
# Out:
#    Unnamed: 0  dno dname       loc
# 2           2   30    IT     delhi
# 3           3   40   Rnd  calcutta

# %%
import pandas as pd
book= pd.read_csv('d:/Datasets/book1.csv')

# %%
book
# Out:
#                                Region                   Country  \
# 0        Middle East and North Africa                Azerbaijan
# 1   Central America and the Caribbean                    Panama
# 2                  Sub-Saharan Africa     Sao Tome and Principe
# 3                  Sub-Saharan Africa     Sao Tome and Principe
# 4   Central America and the Caribbean                    Belize
# 5                              Europe                   Denmark
# 6                              Europe                   Germany
# 7        Middle East and North Africa                    Turkey
# 8                              Europe            United Kingdom
# 9                                Asia                Kazakhstan
# 10  Central America and the Caribbean                     Haiti
# 11                             Europe                     Italy
# 12                             Europe                     Malta
# 13       Middle East and North Africa                    Jordan
# ...

# %%
dept=('d:/datasets/department.csv')

# %%
dept
# Out:
# 'd:/datasets/department.csv'

# %%
dept= pd.read_csv('d:/Datasets/department.csv')

# %%
dept
# Out:
#    Unnamed: 0  dno    dname       loc
# 0           0   10  finance       hyd
# 1           1   20       hr    mumbai
# 2           2   30       IT     delhi
# 3           3   40      Rnd  calcutta

# %%
emp= pd.read_csv('d:/Datasets/employee.csv')

# %%
emp
# Out:
#   employee id        fullname position  salary manager id  department id
# 0     ind-001    Abdul Rehman      CSO  100000        NaN              1
# 1     ind-002       M. Yousuf      CTO   90000    ind-001              1
# 2     ind-003  Joseph D'Souza      CVO   84000    ind-001              1
# 3     ind-004  Mahesh Kalmadi      CWO   70000    ind-002              2
# 4      us-001  Jogender Singh      STO   56000    ind-002              2
# 5      us-002     Syed Mannan      SPO   56000    ind-003              3
# 6     dub-001            John      CTO   50000    ind-002              0

# %%
pd.merge(dept,emp,on='dno',how='left')
# Out:
#    Unnamed: 0_x  dno    dname       loc  Unnamed: 0_y employee id  \
# 0             0   10  finance       hyd             0     ind-001
# 1             1   20       hr    mumbai             1     ind-002
# 2             2   30       IT     delhi             2     ind-003
# 3             3   40      Rnd  calcutta             3     ind-004
#
#          fullname position  salary manager id  department id
# 0    Abdul Rehman      CSO  100000        NaN              1
# 1       M. Yousuf      CTO   90000    ind-001              1
# 2  Joseph D'Souza      CVO   84000    ind-001              1
# 3  Mahesh Kalmadi      CWO   70000    ind-002              2

# %%
emp= pd.read_csv('d:/Datasets/employee.csv')

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
pd.merge(dept,emp,on='dno',how='left')
# Out:
#    Unnamed: 0_x  dno    dname       loc  Unnamed: 0_y employee id  \
# 0             0   10  finance       hyd             0     ind-001
# 1             1   20       hr    mumbai             1     ind-002
# 2             2   30       IT     delhi             2     ind-003
# 3             3   40      Rnd  calcutta             3     ind-004
#
#          fullname position  salary manager id  department id
# 0    Abdul Rehman      CSO  100000        NaN              1
# 1       M. Yousuf      CTO   90000    ind-001              1
# 2  Joseph D'Souza      CVO   84000    ind-001              1
# 3  Mahesh Kalmadi      CWO   70000    ind-002              2

# %%
pd.merge(dept,emp,on='dno',how='outer')
# Out:
#    Unnamed: 0_x  dno    dname       loc  Unnamed: 0_y employee id  \
# 0           0.0   10  finance       hyd             0     ind-001
# 1           1.0   20       hr    mumbai             1     ind-002
# 2           2.0   30       IT     delhi             2     ind-003
# 3           3.0   40      Rnd  calcutta             3     ind-004
# 4           NaN   50      NaN       NaN             4      us-001
# 5           NaN   60      NaN       NaN             5      us-002
# 6           NaN   70      NaN       NaN             6     dub-001
#
#          fullname position  salary manager id  department id
# 0    Abdul Rehman      CSO  100000        NaN              1
# 1       M. Yousuf      CTO   90000    ind-001              1
# 2  Joseph D'Souza      CVO   84000    ind-001              1
# 3  Mahesh Kalmadi      CWO   70000    ind-002              2
# 4  Jogender Singh      STO   56000    ind-002              2
# 5     Syed Mannan      SPO   56000    ind-003              3
# ...

# %%
pd.merge(dept,emp,on='dno',how='right')
# Out:
#    Unnamed: 0_x  dno    dname       loc  Unnamed: 0_y employee id  \
# 0           0.0   10  finance       hyd             0     ind-001
# 1           1.0   20       hr    mumbai             1     ind-002
# 2           2.0   30       IT     delhi             2     ind-003
# 3           3.0   40      Rnd  calcutta             3     ind-004
# 4           NaN   50      NaN       NaN             4      us-001
# 5           NaN   60      NaN       NaN             5      us-002
# 6           NaN   70      NaN       NaN             6     dub-001
#
#          fullname position  salary manager id  department id
# 0    Abdul Rehman      CSO  100000        NaN              1
# 1       M. Yousuf      CTO   90000    ind-001              1
# 2  Joseph D'Souza      CVO   84000    ind-001              1
# 3  Mahesh Kalmadi      CWO   70000    ind-002              2
# 4  Jogender Singh      STO   56000    ind-002              2
# 5     Syed Mannan      SPO   56000    ind-003              3
# ...

# %%
pd.merge(dept,emp,on='dno',how='left')
# Out:
#    Unnamed: 0_x  dno    dname       loc  Unnamed: 0_y employee id  \
# 0             0   10  finance       hyd             0     ind-001
# 1             1   20       hr    mumbai             1     ind-002
# 2             2   30       IT     delhi             2     ind-003
# 3             3   40      Rnd  calcutta             3     ind-004
#
#          fullname position  salary manager id  department id
# 0    Abdul Rehman      CSO  100000        NaN              1
# 1       M. Yousuf      CTO   90000    ind-001              1
# 2  Joseph D'Souza      CVO   84000    ind-001              1
# 3  Mahesh Kalmadi      CWO   70000    ind-002              2

# %%
import math
print (math.sqrt(2))
# Out:
# 1.4142135623730951

# %%
from math import sqrt
print (sqrt(2))
# Out:
# 1.4142135623730951

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'pi',
#  'pow',
#  'radians',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
# radius
r=5
math.pi*r**2
# Out:
# 78.53981633974483

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
math.tan(90)
# Out:
# -1.995200412208242

# %%
import os,sys

# %%
dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'errno',
#  'error',
#  'execl',
#  'execle',
# ...

# %%
dir(sys)
# Out:
# ['__displayhook__',
#  '__doc__',
#  '__excepthook__',
#  '__interactivehook__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__stderr__',
#  '__stdin__',
#  '__stdout__',
#  '_clear_type_cache',
#  '_current_frames',
#  '_debugmallocstats',
#  '_enablelegacywindowsfsencoding',
#  '_getframe',
#  '_git',
#  '_home',
#  '_xoptions',
#  'api_version',
#  'argv',
#  'base_exec_prefix',
#  'base_prefix',
#  'builtin_module_names',
#  'byteorder',
#  'call_tracing',
#  'callstats',
#  'copyright',
#  'displayhook',
#  'dllhandle',
#  'dont_write_bytecode',
#  'exc_info',
#  'excepthook',
#  'exec_prefix',
#  'executable',
#  'exit',
#  'flags',
#  'float_info',
#  'float_repr_style',
#  'get_asyncgen_hooks',
#  'get_coroutine_wrapper',
#  'getallocatedblocks',
#  'getcheckinterval',
#  'getdefaultencoding',
#  'getfilesystemencodeerrors',
#  'getfilesystemencoding',
#  'getprofile',
#  'getrecursionlimit',
#  'getrefcount',
#  'getsizeof',
#  'getswitchinterval',
# ...

# %%
# !cd
# Out:
# C:\Users\admin\Downloads\Data Science Practical\Python library practical

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 80D5-3BF6
#
#  Directory of C:\Users\admin\Downloads\Data Science Practical\Python library practical
#
# 03/10/2020  10:12 PM    <DIR>          .
# 03/10/2020  10:12 PM    <DIR>          ..
# 03/10/2020  10:05 PM    <DIR>          .ipynb_checkpoints
# 03/10/2020  08:24 PM            73,720 100_Numpy_exercises (1).ipynb
# 03/07/2020  10:49 PM           197,036 Best Phython Libraries for Machine Learning.docx
# 03/08/2020  01:10 AM            75,404 Matplotlib Workbook (2).ipynb
# 03/08/2020  12:58 AM            25,316 My Pandas excercise.ipynb
# 03/10/2020  10:05 PM            18,467 numpy I.ipynb
# 03/07/2020  11:11 PM            12,021 numpy session 2 .ipynb
# 03/10/2020  10:02 PM            25,821 pandas 4  merge function.ipynb
# 03/10/2020  08:13 PM            27,351 pandas+1.ipynb
# 03/08/2020  12:56 AM         2,587,646 pandas.plot.ipnby
# 03/08/2020  12:55 AM            83,068 pandas_3 Query like operations (1).ipynb
# ...

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
sys.version
# Out:
# '3.6.5 |Anaconda, Inc.| (default, Mar 29 2018, 13:32:41) [MSC v.1900 64 bit (AMD64)]'

# %%
sys.version_info
# Out:
# sys.version_info(major=3, minor=6, micro=5, releaselevel='final', serial=0)

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.14.3'

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.23.0'

# %%
import matplotlib.pyplot as plt

# %%
plt.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-258ef2d68aad> in <module>()
# ----> 1 plt.__version__
#
# AttributeError: module 'matplotlib.pyplot' has no attribute '__version__'

# %%
vector = np.array([1,2,3])

# %%
vector
# Out:
# array([1, 2, 3])

# %%
matrices = np.array([[1,2,3],[4,5,6],[8,9,0]])

# %%
matrices  # 3 X 3 matrix
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [8, 9, 0]])

# %%
n=(1,2,3)

# %%
n*2
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
n * 2
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
##scalar * vector / matrix
vector
# Out:
# array([1, 2, 3])

# %%
vector *6  #broadcasting
# Out:
# array([ 6, 12, 18])

# %%
matrices*7    #broadcasting
# Out:
# array([[ 7, 14, 21],
#        [28, 35, 42],
#        [56, 63,  0]])

# %%
type(vector)
# Out:
# numpy.ndarray

# %%
type(matrices)
# Out:
# numpy.ndarray

# %%
vector.shape
# Out:
# (3,)

# %%
matrices.shape
# Out:
# (3, 3)

# %%
import numpy as np

# %%
# !pip install numpy
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
player1_score = np.array([50,60,80,20,10])

# %%
player1_score + 10
# Out:
# array([60, 70, 90, 30, 20])

# %%
player2 = [66,77,88,40,50]

# %%
player2 + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-97d94a3d20ee> in <module>()
# ----> 1 player2 + 10
#
# TypeError: can only concatenate list (not "int") to list

# %%
# creating numpy array on pre existing list
player2_score = np.array(player2)

# %%
player2_score +20
# Out:
# array([ 86,  97, 108,  60,  70])

# %%
player2_score[0]
# Out:
# 66

# %%
player1_score[2]
# Out:
# 80

# %%
players = np.array([[50,60,80,20,10],[76, 87, 98, 50, 60],[99,88,10,8,0]])

# %%
players
# Out:
# array([[50, 60, 80, 20, 10],
#        [76, 87, 98, 50, 60],
#        [99, 88, 10,  8,  0]])

# %%
players[1,2]
# Out:
# 98

# %%
players[0,-1]
# Out:
# 10

# %%
type(players)
# Out:
# numpy.ndarray

# %%
np.ndim(players)
# Out:
# 2

# %%
np.ndim(player1_score)
# Out:
# 1

# %%
np.ndim(player2_score)
# Out:
# 1

# %%
john=np.array([[[1,2,3],[5,6,7],[8,9,0]]])

# %%
john
# Out:
# array([[[1, 2, 3],
#         [5, 6, 7],
#         [8, 9, 0]]])

# %%
np.ndim(john)
# Out:
# 3

# %%
players
# Out:
# array([[50, 60, 80, 20, 10],
#        [76, 87, 98, 50, 60],
#        [99, 88, 10,  8,  0]])

# %%
players.max(axis=1) # row wise (Horizontal)
# Out:
# array([80, 98, 99])

# %%
players.max(axis=0)  # column wise (vertical)
# Out:
# array([99, 88, 98, 50, 60])

# %%
players.min(axis=1)  # row wise
# Out:
# array([10, 50,  0])

# %%
players.min(axis=0)   # column wise
# Out:
# array([50, 60, 10,  8,  0])

# %%
players.mean(axis=0)  # column wise
# Out:
# array([75.        , 78.33333333, 62.66666667, 26.        , 23.33333333])

# %%
players.mean(axis=1)  # row wise
# Out:
# array([44. , 74.2, 41. ])

# %%
players
# Out:
# array([[50, 60, 80, 20, 10],
#        [76, 87, 98, 50, 60],
#        [99, 88, 10,  8,  0]])

# %%
players.T     # transpose of a matrix
# Out:
# array([[50, 76, 99],
#        [60, 87, 88],
#        [80, 98, 10],
#        [20, 50,  8],
#        [10, 60,  0]])

# %%
np.sqrt(players)
# Out:
# array([[7.07106781, 7.74596669, 8.94427191, 4.47213595, 3.16227766],
#        [8.71779789, 9.32737905, 9.89949494, 7.07106781, 7.74596669],
#        [9.94987437, 9.38083152, 3.16227766, 2.82842712, 0.        ]])

# %%
# !dir *p*
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 80D5-3BF6
#
#  Directory of C:\Users\admin\Downloads\Data Science Practical\Python library practical
#
# 03/10/2020  10:34 PM    <DIR>          .ipynb_checkpoints
# 03/10/2020  08:24 PM            73,720 100_Numpy_exercises (1).ipynb
# 03/07/2020  10:49 PM           197,036 Best Phython Libraries for Machine Learning.docx
# 03/10/2020  10:17 PM            75,404 Matplotlib Workbook (2).ipynb
# 03/08/2020  12:58 AM            25,316 My Pandas excercise.ipynb
# 03/10/2020  10:05 PM            18,467 numpy I.ipynb
# 03/10/2020  10:50 PM           228,224 numpy pandas & matplotlib practice.ipynb
# 03/10/2020  10:34 PM            12,021 numpy session 2 .ipynb
# 03/10/2020  10:02 PM            25,821 pandas 4  merge function.ipynb
# 03/10/2020  08:13 PM            27,351 pandas+1.ipynb
# 03/08/2020  12:56 AM         2,587,646 pandas.plot.ipnby
# 03/08/2020  12:55 AM            83,068 pandas_3 Query like operations (1).ipynb
# ...

# %%
players
# Out:
# array([[50, 60, 80, 20, 10],
#        [76, 87, 98, 50, 60],
#        [99, 88, 10,  8,  0]])

# %%
np.save('players_np',players)

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 80D5-3BF6
#
#  Directory of C:\Users\admin\Downloads\Data Science Practical\Python library practical
#
# 03/10/2020  10:51 PM    <DIR>          .
# 03/10/2020  10:51 PM    <DIR>          ..
# 03/10/2020  10:34 PM    <DIR>          .ipynb_checkpoints
# 03/10/2020  08:24 PM            73,720 100_Numpy_exercises (1).ipynb
# 03/07/2020  10:49 PM           197,036 Best Phython Libraries for Machine Learning.docx
# 03/10/2020  10:17 PM            75,404 Matplotlib Workbook (2).ipynb
# 03/08/2020  12:58 AM            25,316 My Pandas excercise.ipynb
# 03/10/2020  10:05 PM            18,467 numpy I.ipynb
# 03/10/2020  10:50 PM           228,224 numpy pandas & matplotlib practice.ipynb
# 03/10/2020  10:34 PM            12,021 numpy session 2 .ipynb
# 03/10/2020  10:02 PM            25,821 pandas 4  merge function.ipynb
# 03/10/2020  08:13 PM            27,351 pandas+1.ipynb
# 03/08/2020  12:56 AM         2,587,646 pandas.plot.ipnby
# ...

# %%
# !dir players
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 80D5-3BF6
#
#  Directory of C:\Users\admin\Downloads\Data Science Practical\Python library practical
# File Not Found

# %%
# !dir players*
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 80D5-3BF6
#
#  Directory of C:\Users\admin\Downloads\Data Science Practical\Python library practical
#
# 03/10/2020  10:51 PM               188 players_np.npy
#                1 File(s)            188 bytes
#                0 Dir(s)  101,109,288,960 bytes free

# %%
# Solving following system of linear equation
# 2a + 1b = 35
# 5a + 4b = 94
coeff = np.array([[2,1],[5,4]])
con = np.array([35,94])
np.linalg.solve(coeff,con)
# Out:
# array([15.33333333,  4.33333333])

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
type(emp['fullname'])
# Out:
# pandas.core.series.Series

# %%
type(emp[['employee id','fullname']])
# Out:
# pandas.core.frame.DataFrame

# %%
emp['salary'].head(2)
# Out:
# 0    100000
# 1     90000
# Name: salary, dtype: int64

# %%
emp['fullname'].tail(5)
# Out:
# 2    Joseph D'Souza
# 3    Mahesh Kalmadi
# 4    Jogender Singh
# 5       Syed Mannan
# 6              John
# Name: fullname, dtype: object

# %%
emp[['fullname','salary']].head()
# Out:
#          fullname  salary
# 0    Abdul Rehman  100000
# 1       M. Yousuf   90000
# 2  Joseph D'Souza   84000
# 3  Mahesh Kalmadi   70000
# 4  Jogender Singh   56000

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp2=pd.read_csv('d:/datasets/employee.csv')

# %%
emp2
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp2=pd.read_csv('d:/datasets/employee.csv',index_col=0)

# %%
emp2
# Out:
#    dno employee id        fullname position  salary manager id  department id
# 0   10     ind-001    Abdul Rehman      CSO  100000        NaN              1
# 1   20     ind-002       M. Yousuf      CTO   90000    ind-001              1
# 2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001              1
# 3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002              2
# 4   50      us-001  Jogender Singh      STO   56000    ind-002              2
# 5   60      us-002     Syed Mannan      SPO   56000    ind-003              3
# 6   70     dub-001            John      CTO   50000    ind-002              0

# %%
emp2=pd.read_csv('d:/datasets/employee.csv',index_col=3)

# %%
emp2
# Out:
#                 Unnamed: 0  dno employee id position  salary manager id  \
# fullname
# Abdul Rehman             0   10     ind-001      CSO  100000        NaN
# M. Yousuf                1   20     ind-002      CTO   90000    ind-001
# Joseph D'Souza           2   30     ind-003      CVO   84000    ind-001
# Mahesh Kalmadi           3   40     ind-004      CWO   70000    ind-002
# Jogender Singh           4   50      us-001      STO   56000    ind-002
# Syed Mannan              5   60      us-002      SPO   56000    ind-003
# John                     6   70     dub-001      CTO   50000    ind-002
#
#                 department id
# fullname
# Abdul Rehman                1
# M. Yousuf                   1
# Joseph D'Souza              1
# Mahesh Kalmadi              2
# Jogender Singh              2
# Syed Mannan                 3
# John                        0

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp.iloc[6]
# Out:
# Unnamed: 0             6
# dno                   70
# employee id      dub-001
# fullname            John
# position             CTO
# salary             50000
# manager id       ind-002
# department id          0
# Name: 6, dtype: object

# %%
emp.loc[0]
# Out:
# Unnamed: 0                  0
# dno                        10
# employee id           ind-001
# fullname         Abdul Rehman
# position                  CSO
# salary                 100000
# manager id                NaN
# department id               1
# Name: 0, dtype: object

# %%
emp
# Out:
#    Unnamed: 0  dno employee id        fullname position  salary manager id  \
# 0           0   10     ind-001    Abdul Rehman      CSO  100000        NaN
# 1           1   20     ind-002       M. Yousuf      CTO   90000    ind-001
# 2           2   30     ind-003  Joseph D'Souza      CVO   84000    ind-001
# 3           3   40     ind-004  Mahesh Kalmadi      CWO   70000    ind-002
# 4           4   50      us-001  Jogender Singh      STO   56000    ind-002
# 5           5   60      us-002     Syed Mannan      SPO   56000    ind-003
# 6           6   70     dub-001            John      CTO   50000    ind-002
#
#    department id
# 0              1
# 1              1
# 2              1
# 3              2
# 4              2
# 5              3
# 6              0

# %%
emp=pd.read_csv('d:/datasets/employee.csv',index_col=3)

# %%
emp
# Out:
#                 Unnamed: 0  dno employee id position  salary manager id  \
# fullname
# Abdul Rehman             0   10     ind-001      CSO  100000        NaN
# M. Yousuf                1   20     ind-002      CTO   90000    ind-001
# Joseph D'Souza           2   30     ind-003      CVO   84000    ind-001
# Mahesh Kalmadi           3   40     ind-004      CWO   70000    ind-002
# Jogender Singh           4   50      us-001      STO   56000    ind-002
# Syed Mannan              5   60      us-002      SPO   56000    ind-003
# John                     6   70     dub-001      CTO   50000    ind-002
#
#                 department id
# fullname
# Abdul Rehman                1
# M. Yousuf                   1
# Joseph D'Souza              1
# Mahesh Kalmadi              2
# Jogender Singh              2
# Syed Mannan                 3
# John                        0

# %%
emp.loc['Abdul Rehman']
# Out:
# Unnamed: 0             0
# dno                   10
# employee id      ind-001
# position             CSO
# salary            100000
# manager id           NaN
# department id          1
# Name: Abdul Rehman, dtype: object

# %%
emp.index_col=0

# %%
emp
# Out:
#                 Unnamed: 0  dno employee id position  salary manager id  \
# fullname
# Abdul Rehman             0   10     ind-001      CSO  100000        NaN
# M. Yousuf                1   20     ind-002      CTO   90000    ind-001
# Joseph D'Souza           2   30     ind-003      CVO   84000    ind-001
# Mahesh Kalmadi           3   40     ind-004      CWO   70000    ind-002
# Jogender Singh           4   50      us-001      STO   56000    ind-002
# Syed Mannan              5   60      us-002      SPO   56000    ind-003
# John                     6   70     dub-001      CTO   50000    ind-002
#
#                 department id
# fullname
# Abdul Rehman                1
# M. Yousuf                   1
# Joseph D'Souza              1
# Mahesh Kalmadi              2
# Jogender Singh              2
# Syed Mannan                 3
# John                        0

# %%
dept=pd.read_csv('d:/datasets/department.csv')

# %%
dept
# Out:
#    Unnamed: 0  dno    dname       loc
# 0           0   10  finance       hyd
# 1           1   20       hr    mumbai
# 2           2   30       IT     delhi
# 3           3   40      Rnd  calcutta
# 4           4   50  testing    madras
# 5           5   60   coding  banglore

# %%
dept.loc[5]
# Out:
# Unnamed: 0           5
# dno                 60
# dname           coding
# loc           banglore
# Name: 5, dtype: object

# %%
dept=pd.read_csv('d:/datasets/department.csv',index_col= 2)

# %%
dept
# Out:
#          Unnamed: 0  dno       loc
# dname
# finance           0   10       hyd
# hr                1   20    mumbai
# IT                2   30     delhi
# Rnd               3   40  calcutta
# testing           4   50    madras
# coding            5   60  banglore

# %%
dept.iloc[1]
# Out:
# Unnamed: 0         1
# dno               20
# loc           mumbai
# Name: hr, dtype: object

# %%
dept=pd.read_csv('d:/datasets/department.csv',index_col= 0)

# %%
dept
# Out:
#    dno    dname       loc
# 0   10  finance       hyd
# 1   20       hr    mumbai
# 2   30       IT     delhi
# 3   40      Rnd  calcutta
# 4   50  testing    madras
# 5   60   coding  banglore

# %%
dept.loc[2]
# Out:
# dno         30
# dname       IT
# loc      delhi
# Name: 2, dtype: object

# %%
dept.iloc[3]
# Out:
# dno            40
# dname         Rnd
# loc      calcutta
# Name: 3, dtype: object

# %%
url = 'https://raw.github.com/pandas-dev/pandas/master/pandas/tests/data/tips.csv'

# %%
url
# Out:
# 'https://raw.github.com/pandas-dev/pandas/master/pandas/tests/data/tips.csv'

# %%
tips=pd.read_csv(url)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips[['total_bill','tip','sex','smoker','day','time']].head(10)
# Out:
#    total_bill   tip     sex smoker  day    time
# 0       16.99  1.01  Female     No  Sun  Dinner
# 1       10.34  1.66    Male     No  Sun  Dinner
# 2       21.01  3.50    Male     No  Sun  Dinner
# 3       23.68  3.31    Male     No  Sun  Dinner
# 4       24.59  3.61  Female     No  Sun  Dinner
# 5       25.29  4.71    Male     No  Sun  Dinner
# 6        8.77  2.00    Male     No  Sun  Dinner
# 7       26.88  3.12    Male     No  Sun  Dinner
# 8       15.04  1.96    Male     No  Sun  Dinner
# 9       14.78  3.23    Male     No  Sun  Dinner

# %%
tips[tips['time']=='Dinner']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips[tips['time']=='lunch']
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
tips[tips['time']=='Lunch']
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 77        27.20  4.00    Male     No  Thur  Lunch     4
# 78        22.76  3.00    Male     No  Thur  Lunch     2
# 79        17.29  2.71    Male     No  Thur  Lunch     2
# 80        19.44  3.00    Male    Yes  Thur  Lunch     2
# 81        16.66  3.40    Male     No  Thur  Lunch     2
# 82        10.07  1.83  Female     No  Thur  Lunch     1
# 83        32.68  5.00    Male    Yes  Thur  Lunch     2
# 84        15.98  2.03    Male     No  Thur  Lunch     2
# 85        34.83  5.17  Female     No  Thur  Lunch     4
# 86        13.03  2.00    Male     No  Thur  Lunch     2
# 87        18.28  4.00    Male     No  Thur  Lunch     2
# 88        24.71  5.85    Male     No  Thur  Lunch     2
# 89        21.16  3.00    Male     No  Thur  Lunch     2
# 117       10.65  1.50  Female     No  Thur  Lunch     2
# 118       12.43  1.80  Female     No  Thur  Lunch     2
# 119       24.08  2.92  Female     No  Thur  Lunch     4
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 4))
#axes
plt.subplot(131)
plt.bar(names, values)
#axes
plt.subplot(132)
plt.scatter(names, values)

plt.subplot(133)
plt.plot(names, values)

plt.suptitle('Categorical Plotting')
plt.show()

# %%
import pandas as pd
import seaborn as sns
t=pd.read_csv('d:/datasets/Titanic_sur_train.csv')

# %%
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.countplot(x='Survived',hue='Sex',data=t)

# %%
sns.countplot(x='Survived',hue='Pclass',data=t)

# %%
sns.countplot(x='Survived',hue='SibSp',data=t)

# %%
sns.countplot(x='Survived',hue='Parch',data=t)

# %%
sns.distplot(t['Age'].dropna(),kde=False,bins=30)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(t['PassengerId'].dropna(),kde=False,bins=30)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(t['SibSp'].dropna(),kde=False,bins=30)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# !pip install cufflinks
# Out:
# ...
#   Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000000046EA710>: Failed to establish a new connection: [Errno 11004] getaddrinfo failed',)': /simple/cufflinks/
#   Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000000046EA668>: Failed to establish a new connection: [Errno 11004] getaddrinfo failed',)': /simple/cufflinks/
#   Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000000046EA5F8>: Failed to establish a new connection: [Errno 11004] getaddrinfo failed',)': /simple/cufflinks/
# ...

# %%
t['Fare'].isns(kind='hist',bins=30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-5914be8800f4> in <module>()
# ----> 1 t['Fare'].isns(kind='hist',bins=30)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'isns'

# %%
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
t['Fare'].iplot(kind='hist',bins=30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-97877120628a> in <module>
# ----> 1 t['Fare'].iplot(kind='hist',bins=30)
#
# NameError: name 't' is not defined

# %%
t['Fare'].max()
# Out:
# 512.3292

# %%
t['Fare'].min()
# Out:
# 0.0

# %%
t.sort_values(by='Fare',ascending=True)['Fare']
# Out:
# 271      0.0000
# 597      0.0000
# 302      0.0000
# 633      0.0000
# 277      0.0000
# 413      0.0000
# 674      0.0000
# 263      0.0000
# 466      0.0000
# 732      0.0000
# 179      0.0000
# 806      0.0000
# 481      0.0000
# 822      0.0000
# 815      0.0000
# 378      4.0125
# 872      5.0000
# 326      6.2375
# 843      6.4375
# 818      6.4500
# 371      6.4958
# 202      6.4958
# 654      6.7500
# 143      6.7500
# 411      6.8583
# 825      6.9500
# 129      6.9750
# 804      6.9750
# 477      7.0458
# 611      7.0500
#          ...
# 31     146.5208
# 708    151.5500
# 498    151.5500
# 305    151.5500
# 297    151.5500
# 609    153.4625
# 332    153.4625
# 268    153.4625
# 856    164.8667
# 318    164.8667
# 779    211.3375
# 730    211.3375
# 689    211.3375
# 377    211.5000
# 527    221.7792
# 700    227.5250
# 380    227.5250
# 557    227.5250
# 716    227.5250
# 118    247.5208
# 299    247.5208
# 742    262.3750
# 311    262.3750
# 27     263.0000
# ...

# %%
t.sort_values(by='Fare',ascending=False)['Fare']
# Out:
# 258    512.3292
# 737    512.3292
# 679    512.3292
# 88     263.0000
# 27     263.0000
# 341    263.0000
# 438    263.0000
# 311    262.3750
# 742    262.3750
# 118    247.5208
# 299    247.5208
# 557    227.5250
# 700    227.5250
# 380    227.5250
# 716    227.5250
# 527    221.7792
# 377    211.5000
# 730    211.3375
# 779    211.3375
# 689    211.3375
# 318    164.8667
# 856    164.8667
# 268    153.4625
# 332    153.4625
# 609    153.4625
# 498    151.5500
# 305    151.5500
# 297    151.5500
# 708    151.5500
# 195    146.5208
#          ...
# 363      7.0500
# 477      7.0458
# 129      6.9750
# 804      6.9750
# 825      6.9500
# 411      6.8583
# 654      6.7500
# 143      6.7500
# 202      6.4958
# 371      6.4958
# 818      6.4500
# 843      6.4375
# 326      6.2375
# 872      5.0000
# 378      4.0125
# 466      0.0000
# 597      0.0000
# 271      0.0000
# 277      0.0000
# 806      0.0000
# 481      0.0000
# 302      0.0000
# 179      0.0000
# 263      0.0000
# ...

# %%
# !ls *.csv
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !cat studyhours.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
import matplotlib.pyplot as plt
sh = pd.read_csv('d:/datasets/studyhours.csv')

# %%
sh
# Out:
#     hours_studies  marks_secured
# 0              50             40
# 1              55             42
# 2              60             44
# 3              65             46
# 4              70             48
# 5              75             50
# 6              80             52
# 7              85             54
# 8              90             56
# 9              95             58
# 10            100             60
# 11            105             64
# 12            110             68
# 13            115             72
# 14            120             74
# 15            125             80

# %%
sh.corr()
# Out:
#                hours_studies  marks_secured
# hours_studies        1.00000        0.98714
# marks_secured        0.98714        1.00000

# %%
x = sh['hours_studies']
y = sh['marks_secured']

plt.bar(x,y)
plt.title('Relationship between hours studies and marks secured')
plt.xlabel('Hours')
plt.ylabel('Marks')
plt.show()
plt.savefig('studyres')

# %%
x = sh['hours_studies']
y = sh['marks_secured']

plt.scatter(x,y)
plt.title('Relationship between hours studies and marks secured')
plt.xlabel('Hours')
plt.ylabel('Marks')
plt.show()

# %%
x = sh['hours_studies']
y = sh['marks_secured']

plt.bar(x,y)
plt.title('Relationship between hours studies and marks secured')
plt.xlabel('Hours')
plt.ylabel('Marks')
plt.show()
plt.savefig('studyres')

# %%
# !ls stu*
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
dataset=sns.load_dataset('d:/datasets/titanic.csv')
sns.jointplot(x='age', y='fare', data=dataset)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ...

# %%
sns.load_dataset

# %%
dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
sns.jointplot(x='age', y='fare', data=dataset, kind='hex')
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
dataset = dataset.dropna()

# %%
sns.rugplot(dataset['fare'])

# %%
sns.boxplot(x='sex', y='age', data=dataset)

# %%
url = 'https://raw.github.com/pandas-dev/pandas/master/pandas/tests/data/tips.csv'

# %% [raw]
# url

# %%
url
# Out:
# 'https://raw.github.com/pandas-dev/pandas/master/pandas/tests/data/tips.csv'

# %%
import pandas as pd

# %%
tips = pd.read_csv(url)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[['total_bill','sex','smoker','day']].head()
# Out:
#    total_bill     sex smoker  day
# 0       16.99  Female     No  Sun
# 1       10.34    Male     No  Sun
# 2       21.01    Male     No  Sun
# 3       23.68    Male     No  Sun
# 4       24.59  Female     No  Sun

# %%
tips.head(10) # Selet * from tips limit 10;
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
tips[tips['time']=='Dinner']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
tips[tips['time']=='Lunch']
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 77        27.20  4.00    Male     No  Thur  Lunch     4
# 78        22.76  3.00    Male     No  Thur  Lunch     2
# 79        17.29  2.71    Male     No  Thur  Lunch     2
# 80        19.44  3.00    Male    Yes  Thur  Lunch     2
# 81        16.66  3.40    Male     No  Thur  Lunch     2
# ..          ...   ...     ...    ...   ...    ...   ...
# 222        8.58  1.92    Male    Yes   Fri  Lunch     1
# 223       15.98  3.00  Female     No   Fri  Lunch     3
# 224       13.42  1.58    Male    Yes   Fri  Lunch     2
# 225       16.27  2.50  Female    Yes   Fri  Lunch     2
# 226       10.09  2.00  Female    Yes   Fri  Lunch     2
#
# [68 rows x 7 columns]

# %%
tips[tips['sex'] == 'Male']   # select * from tips where sex='Male'
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
# select * from tips where tiem='Dinner' and sex='Male'

t = tips[(tips['time'] == 'Dinner') & (tips['sex'] == 'Male') & (tips['size'] >3 )]

# %%
t
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 7         26.88  3.12  Male     No  Sun  Dinner     4
# 13        18.43  3.00  Male     No  Sun  Dinner     4
# 23        39.42  7.58  Male     No  Sat  Dinner     4
# 25        17.81  2.34  Male     No  Sat  Dinner     4
# 31        18.35  2.50  Male     No  Sat  Dinner     4
# 44        30.40  5.60  Male     No  Sun  Dinner     4
# 47        32.40  6.00  Male     No  Sun  Dinner     4
# 54        25.56  4.34  Male     No  Sun  Dinner     4
# 56        38.01  3.00  Male    Yes  Sat  Dinner     4
# 59        48.27  6.73  Male     No  Sat  Dinner     4
# 63        18.29  3.76  Male    Yes  Sat  Dinner     4
# 95        40.17  4.73  Male    Yes  Fri  Dinner     4
# 116       29.93  5.07  Male     No  Sun  Dinner     4
# 153       24.55  2.00  Male     No  Sun  Dinner     4
# 154       19.77  2.00  Male     No  Sun  Dinner     4
# ...

# %%
t.to_csv('tips')

# %%
t
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 7         26.88  3.12  Male     No  Sun  Dinner     4
# 13        18.43  3.00  Male     No  Sun  Dinner     4
# 23        39.42  7.58  Male     No  Sat  Dinner     4
# 25        17.81  2.34  Male     No  Sat  Dinner     4
# 31        18.35  2.50  Male     No  Sat  Dinner     4
# 44        30.40  5.60  Male     No  Sun  Dinner     4
# 47        32.40  6.00  Male     No  Sun  Dinner     4
# 54        25.56  4.34  Male     No  Sun  Dinner     4
# 56        38.01  3.00  Male    Yes  Sat  Dinner     4
# 59        48.27  6.73  Male     No  Sat  Dinner     4
# 63        18.29  3.76  Male    Yes  Sat  Dinner     4
# 95        40.17  4.73  Male    Yes  Fri  Dinner     4
# 116       29.93  5.07  Male     No  Sun  Dinner     4
# 153       24.55  2.00  Male     No  Sun  Dinner     4
# 154       19.77  2.00  Male     No  Sun  Dinner     4
# ...

# %%
tips.to_csv('d:/datasets/tips.csv')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
t.to_csv('d:/datasets/tips2.csv')

# %%
t
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 7         26.88  3.12  Male     No  Sun  Dinner     4
# 13        18.43  3.00  Male     No  Sun  Dinner     4
# 23        39.42  7.58  Male     No  Sat  Dinner     4
# 25        17.81  2.34  Male     No  Sat  Dinner     4
# 31        18.35  2.50  Male     No  Sat  Dinner     4
# 44        30.40  5.60  Male     No  Sun  Dinner     4
# 47        32.40  6.00  Male     No  Sun  Dinner     4
# 54        25.56  4.34  Male     No  Sun  Dinner     4
# 56        38.01  3.00  Male    Yes  Sat  Dinner     4
# 59        48.27  6.73  Male     No  Sat  Dinner     4
# 63        18.29  3.76  Male    Yes  Sat  Dinner     4
# 95        40.17  4.73  Male    Yes  Fri  Dinner     4
# 116       29.93  5.07  Male     No  Sun  Dinner     4
# 153       24.55  2.00  Male     No  Sun  Dinner     4
# 154       19.77  2.00  Male     No  Sun  Dinner     4
# ...

# %%
tips[(tips['time'] == 'Dinner') & ((tips['sex'] == 'Male') | (tips['size'] >3 ))]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [131 rows x 7 columns]

# %%
tips[['total_bill','tip','smoker','time']].head()
# Out:
#    total_bill   tip smoker    time
# 0       16.99  1.01     No  Dinner
# 1       10.34  1.66     No  Dinner
# 2       21.01  3.50     No  Dinner
# 3       23.68  3.31     No  Dinner
# 4       24.59  3.61     No  Dinner

# %%
tips.head(10) # Selet * from tips limit 10;
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
tips[tips['sex'] == 'Male']   # select * from tips where sex='Male'
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
# select * from tips where tiem='Dinner' and sex='Male'
t = tips[(tips['time'] == 'Dinner') & (tips['sex'] == 'Male') & (tips['size'] >3 )]

# %%
t
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 7         26.88  3.12  Male     No  Sun  Dinner     4
# 13        18.43  3.00  Male     No  Sun  Dinner     4
# 23        39.42  7.58  Male     No  Sat  Dinner     4
# 25        17.81  2.34  Male     No  Sat  Dinner     4
# 31        18.35  2.50  Male     No  Sat  Dinner     4
# 44        30.40  5.60  Male     No  Sun  Dinner     4
# 47        32.40  6.00  Male     No  Sun  Dinner     4
# 54        25.56  4.34  Male     No  Sun  Dinner     4
# 56        38.01  3.00  Male    Yes  Sat  Dinner     4
# 59        48.27  6.73  Male     No  Sat  Dinner     4
# 63        18.29  3.76  Male    Yes  Sat  Dinner     4
# 95        40.17  4.73  Male    Yes  Fri  Dinner     4
# 116       29.93  5.07  Male     No  Sun  Dinner     4
# 153       24.55  2.00  Male     No  Sun  Dinner     4
# 154       19.77  2.00  Male     No  Sun  Dinner     4
# ...

# %%
# Import package
import requests

# Assign URL to variable: url
url = "https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exintro=&titles=gold"

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Decode the JSON data into a dictionary: json_data
json_data = r.json()

print (json_data)

# Print the Wikipedia page extract
#pizza_extract = json_data['query']['pages']['24768']['extract']
#print(pizza_extract)
# Out:
# {'batchcomplete': '', 'warnings': {'extracts': {'*': 'HTML may be malformed and/or unbalanced and may omit inline images. Use at your own risk. Known problems are listed at https://www.mediawiki.org/wiki/Extension:TextExtracts#Caveats.'}}, 'query': {'normalized': [{'from': 'gold', 'to': 'Gold'}], 'pages': {'12240': {'pageid': 12240, 'ns': 0, 'title': 'Gold', 'extract': '<p class="mw-empty-elt">\n</p>\n\n<p class="mw-empty-elt">\n</p>\n<p><b>Gold</b> is a chemical element with the symbol <b>Au</b> (from Latin: <i lang="la">aurum</i>) and atomic number 79, making it one of the higher atomic number elements that occur naturally. In its purest form, it is a bright, slightly reddish yellow, dense, soft, malleable, and ductile metal. Chemically, gold is a transition metal and a group 11 element. It is one of the least reactive chemical elements and is solid under standard conditions. Gold often occurs in free elemental (native) form, as nuggets or grains, in rocks, in veins, and in alluvia
# ...

# %%
topic = input("Enter your choice of Topic:")
url = "https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exintro=&titles={}".format(topic)

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Decode the JSON data into a dictionary: json_data
json_data = r.json()
json_data
# Out:
# Enter your choice of Topic:diamond
# {'batchcomplete': '',
#  'warnings': {'extracts': {'*': 'HTML may be malformed and/or unbalanced and may omit inline images. Use at your own risk. Known problems are listed at https://www.mediawiki.org/wiki/Extension:TextExtracts#Caveats.'}},
#  'query': {'normalized': [{'from': 'diamond', 'to': 'Diamond'}],
#   'pages': {'8082': {'pageid': 8082,
#     'ns': 0,
#     'title': 'Diamond',
# ...
